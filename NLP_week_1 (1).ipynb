# %% [markdown]
# # New section

# %%
import nltk

# %% [markdown]
# nltk.download('gutenberg')

# %% [markdown]
# nltk.download('genesis')

# %% [markdown]
# nltk.download('inaugural')

# %% [markdown]
# nltk.download('nps_chat')

# %% [markdown]
# nltk.download('webtext')

# %% [markdown]
# nltk.download('treebank')

# %%
from nltk.book import *
# Out:
# *** Introductory Examples for the NLTK Book ***
# Loading text1, ..., text9 and sent1, ..., sent9
# Type the name of the text or sentence to view it.
# Type: 'texts()' or 'sents()' to list the materials.
# text1: Moby Dick by Herman Melville 1851
# text2: Sense and Sensibility by Jane Austen 1811
# text3: The Book of Genesis
# text4: Inaugural Address Corpus
# text5: Chat Corpus
# text6: Monty Python and the Holy Grail
# text7: Wall Street Journal
# text8: Personals Corpus
# text9: The Man Who Was Thursday by G . K . Chesterton 1908

# %%
text1
# Out:
# <Text: Moby Dick by Herman Melville 1851>

# %%
text1.concordance("monstrous")
# Out:
# Displaying 11 of 11 matches:
# ong the former , one was of a most monstrous size . ... This came towards us ,
# ON OF THE PSALMS . " Touching that monstrous bulk of the whale or ork we have r
# ll over with a heathenish array of monstrous clubs and spears . Some were thick
# d as you gazed , and wondered what monstrous cannibal and savage could ever hav
# that has survived the flood ; most monstrous and most mountainous ! That Himmal
# they might scout at Moby Dick as a monstrous fable , or still worse and more de
# th of Radney .'" CHAPTER 55 Of the Monstrous Pictures of Whales . I shall ere l
# ing Scenes . In connexion with the monstrous pictures of whales , I am strongly
# ere to enter upon those still more monstrous stories of them which are to be fo
# ght have been rummaged out of this monstrous cabinet there is no telling . But
# of Whale - Bones ; for Whales of a monstrous size are oftentimes cast up dead u

# %%
text1.similar("monstrous")
# Out:
# true contemptible christian abundant few part mean careful puzzled
# mystifying passing curious loving wise doleful gamesome singular
# delightfully perilous fearless

# %%
text2.common_contexts(["monstrous", "very"])

#examine just the contexts that are shared by two or more words, such as monstrous and very
# Out:
# a_pretty am_glad a_lucky is_pretty be_glad

# %%
text4.dispersion_plot(["citizens", "democracy", "freedom", "duties", "America"])

#determines the location of a word in the text

# %%
# text3.generate() #generate random texts

# %% [markdown]
# # NLTK

# %% [markdown]
# # Tokenization

# %%
from nltk import word_tokenize
from nltk import sent_tokenize

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\HP\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
en = r"C:\Users\HP\Downloads\Harry_en.txt"

# %%
en_content = open(en,encoding='utf-8').read()

# %%
wordtokens_en = word_tokenize(en_content)

# %%
wordtokens_en
# Out:
# ['``',
#  'The',
#  'bang',
#  'was',
#  'like',
#  'a',
#  'cannon',
#  'blast',
#  ',',
#  'and',
#  'the',
#  'golden',
#  'flames',
#  'that',
#  'erupted',
#  'between',
#  'them',
#  ',',
#  'at',
#  'the',
#  'dead',
#  'center',
#  'of',
#  'the',
#  'circle',
#  'they',
#  'had',
#  'been',
#  'treading',
#  ',',
#  'marked',
#  'the',
#  'point',
#  'where',
#  'the',
#  'spells',
#  'collided',
#  '.',
#  '``',
#  ',',
#  "''",
#  'Harry',
#  'saw',
#  'Voldemort',
#  '’',
#  's',
#  'green',
#  'jet',
#  'meet',
#  'his',
#  'own',
#  'spell',
#  ',',
#  'saw',
#  'the',
#  'Elder',
#  'Wand',
#  'fly',
#  'high',
#  ',',
#  'dark',
#  'against',
#  'the',
#  'sunrise',
#  ',',
#  'spinning',
#  'across',
#  'the',
#  'enchanted',
#  'ceiling',
#  'like',
#  'the',
#  'head',
#  'of',
#  'Nagini',
#  ',',
#  'spinning',
#  'through',
#  'the',
#  'air',
#  'toward',
#  'the',
#  'master',
#  'it',
#  'would',
#  'not',
#  'kill',
#  ',',
#  'who',
#  'had',
#  'come',
#  'to',
#  'take',
#  'full',
#  'possession',
#  'of',
#  'it',
#  'at',
#  'last',
#  '.',
#  '``',
#  ',',
#  "''",
#  'And',
#  'Harry',
#  ',',
#  'with',
#  'the',
#  'unerring',
#  'skill',
#  'of',
#  'the',
#  'Seeker',
#  ',',
#  'caught',
#  'the',
#  'wand',
#  'in',
#  'his',
#  'free',
#  'hand',
#  'as',
#  'Voldemort',
#  'fell',
#  'backward',
#  ',',
#  'arms',
#  'splayed',
#  ',',
#  'the',
#  'slit',
#  'pupils',
#  'of',
#  'the',
#  'scarlet',
#  'eyes',
#  'rolling',
#  'upward',
#  '.',
#  '``',
#  ',',
#  "''",
#  'Tom',
#  'Riddle',
#  'hit',
#  'the',
#  'floor',
#  'with',
#  'a',
#  'mundane',
#  'finality',
#  ',',
#  'his',
#  'body',
#  'feeble',
#  'and',
#  'shrunken',
#  ',',
#  'the',
#  'white',
#  'hands',
#  'empty',
#  ',',
#  'the',
#  'snakelike',
#  'face',
#  'vacant',
#  'and',
#  'unknowing',
#  '.',
#  '``',
#  ',',
#  "''",
#  'Voldemort',
#  'was',
#  'dead',
#  ',',
#  'killed',
#  'by',
#  'his',
#  'own',
#  'rebounding',
#  'curse',
#  ',',
#  'and',
#  'Harry',
#  'stood',
#  'with',
#  'two',
#  'wands',
#  'in',
#  'his',
#  'hand',
#  ',',
#  'staring',
#  'down',
#  'at',
#  'his',
#  'enemy',
#  '’',
#  's',
#  'shell',
#  '.',
#  '``',
#  ',',
#  "''",
#  'One',
#  'shivering',
#  'second',
#  'of',
#  'silence',
#  ',',
#  'the',
#  'shock',
#  'of',
#  'the',
#  'moment',
#  'suspended',
#  ':',
#  'and',
#  'then',
#  'the',
#  'tumult',
#  'broke',
#  'around',
#  'Harry',
#  'as',
#  'the',
#  'screams',
#  'and',
#  'the',
#  'cheers',
#  'and',
#  'the',
#  'roars',
#  'of',
#  'the',
#  'watchers',
#  'rent',
#  'the',
#  'air',
#  '.',
#  '``',
#  ',',
#  "''",
#  'The',
#  'fierce',
#  'new',
#  'sun',
#  'dazzled',
#  'the',
#  'windows',
#  'as',
#  'they',
#  'thundered',
#  'toward',
#  'him',
#  ',',
#  'and',
#  'the',
#  'first',
#  'to',
#  'reach',
#  'him',
#  'were',
#  'Ron',
#  'and',
#  'Hermione',
#  ',',
#  'and',
#  'it',
#  'was',
#  'their',
#  'arms',
#  'that',
#  'were',
#  'wrapped',
#  'around',
#  'him',
#  ',',
#  'their',
#  'incomprehensible',
#  'shouts',
#  'that',
#  'deafened',
#  'him',
#  '.',
#  '``',
#  ',',
#  "''",
#  'Then',
#  'Ginny',
#  ',',
#  'Neville',
#  ',',
#  'and',
#  'Luna',
#  'were',
#  'there',
#  ',',
#  'and',
#  'then',
#  'all',
#  'the',
#  'Weasleys',
#  'and',
#  'Hagrid',
#  ',',
#  'and',
#  'Kingsley',
#  'and',
#  'McGonagall',
#  'and',
#  'Flitwick',
#  'and',
#  'Sprout',
#  ',',
#  'and',
#  'Harry',
#  'could',
#  'not',
#  'hear',
#  'a',
#  'word',
#  'that',
#  'anyone',
#  'was',
#  'shouting',
#  ',',
#  'nor',
#  'tell',
#  'whose',
#  'hands',
#  'were',
#  'seizing',
#  'him',
#  ',',
#  'pulling',
#  'him',
#  ',',
#  'trying',
#  'to',
#  'hug',
#  'some',
#  'part',
#  'of',
#  'him',
#  ',',
#  'hundreds',
#  'of',
#  'them',
#  'pressing',
#  'in',
#  ',',
#  'all',
#  'of',
#  'them',
#  'determined',
#  'to',
#  'touch',
#  'the',
#  'Boy',
#  'Who',
#  'Lived',
#  ',',
#  'the',
#  'reason',
#  'it',
#  'was',
#  'over',
#  'at',
#  'last',
#  '.',
#  '``',
#  ',',
#  "''",
#  'The',
#  'sun',
#  'rose',
#  'steadily',
#  'over',
#  'Hogwarts',
#  ',',
#  'and',
#  'the',
#  'Great',
#  'Hall',
#  'blazed',
#  'with',
#  'life',
#  'and',
#  'light',
#  '.',
#  '``',
#  ',',
#  "''",
#  'Harry',
#  'was',
#  'an',
#  'indispensable',
#  'part',
#  'of',
#  'the',
#  'mingled',
#  'outpourings',
#  'of',
#  'jubilation',
#  'and',
#  'mourning',
#  ',',
#  'of',
#  'grief',
#  'and',
#  'celebration',
#  '.',
#  '``',
#  ',',
#  "''",
#  'They',
#  'wanted',
#  'him',
#  'there',
#  'with',
#  'them',
#  ',',
#  'their',
#  'leader',
#  'and',
#  'symbol',
#  ',',
#  'their',
#  'savior',
#  'and',
#  'their',
#  'guide',
#  ',',
#  'and',
#  'that',
#  'he',
#  'had',
#  'not',
#  'slept',
#  ',',
#  'that',
#  'he',
#  'craved',
#  'the',
#  'company',
#  'of',
#  'only',
#  'a',
#  'few',
#  'of',
#  'them',
#  ',',
#  'seemed',
#  'to',
#  'occur',
#  'to',
#  'no',
#  'one',
#  '.',
#  '``',
#  ',',
#  "''",
#  'He',
#  'must',
#  'speak',
#  'to',
#  'the',
#  'bereaved',
#  ',',
#  'clasp',
#  'their',
#  'hands',
#  ',',
#  'witness',
#  'their',
#  'tears',
#  ',',
#  'receive',
#  'their',
#  'thanks',
#  ',',
#  'hear',
#  'the',
#  'news',
#  'now',
#  'creeping',
#  'in',
#  'from',
#  'every',
#  'quarter',
#  'as',
#  'the',
#  'morning',
#  'drew',
#  'on',
#  ';',
#  'that',
#  'the',
#  'Imperiused',
#  'up',
#  'and',
#  'down',
#  'the',
#  'country',
#  'had',
#  'come',
#  'back',
#  'to',
#  'themselves',
#  ',',
#  'that',
#  'Death',
#  'Eaters',
#  'were',
#  'fleeing',
#  'or',
#  'else',
#  'being',
#  'captured',
#  ',',
#  'that',
#  'the',
#  'innocent',
#  'of',
#  'Azkaban',
#  'were',
#  'being',
#  'released',
#  'at',
#  'that',
#  'very',
#  'moment',
#  ',',
#  'and',
#  'that',
#  'Kingsley',
#  'Shacklebolt',
#  'had',
#  'been',
#  'named',
#  'temporary',
#  'Minister',
#  'of',
#  'Magic',
#  '.',
#  '...',
#  "''",
#  ',',
#  "''",
#  'They',
#  'moved',
#  'Voldemort',
#  '’',
#  's',
#  'body',
#  'and',
#  'laid',
#  'it',
#  'in',
#  'a',
#  'chamber',
#  'off',
#  'the',
#  'Hall',
#  ',',
#  'away',
#  'from',
#  'the',
#  'bodies',
#  'of',
#  'Fred',
#  ',',
#  'Tonks',
#  ',',
#  'Lupin',
#  ',',
#  'Colin',
#  'Creevey',
#  ',',
#  'and',
#  'fifty',
#  'others',
#  'who',
#  'had',
#  'died',
#  'fighting',
#  'him',
#  '.',
#  '``',
#  ',',
#  "''",
#  'McGonagall',
#  'had',
#  'replaced',
#  'the',
#  'House',
#  'tables',
#  ',',
#  'but',
#  'nobody',
#  'was',
#  'sitting',
#  'according',
#  'to',
#  'House',
#  'anymore',
#  "''",
#  ',',
#  "''",
#  'All',
#  'were',
#  'jumbled',
#  'together',
#  ',',
#  'teachers',
#  'and',
#  'pupils',
#  ',',
#  'ghosts',
#  'and',
#  'parents',
#  ',',
#  'centaurs',
#  'and',
#  'house-',
#  'elves',
#  ',',
#  'and',
#  'Firenze',
#  'lay',
#  'recovering',
#  'in',
#  'a',
#  'corner',
#  ',',
#  'and',
#  'Grawp',
#  'peered',
#  'in',
#  'through',
#  'a',
#  'smashed',
#  'window',
#  ',',
#  'and',
#  'people',
#  'were',
#  'throwing',
#  'food',
#  'into',
#  'his',
#  'laughing',
#  'mouth',
#  '.',
#  '``',
#  ',',
#  "''",
#  'After',
#  'a',
#  'while',
#  ',',
#  'exhausted',
#  'and',
#  'drained',
#  ',',
#  'Harry',
#  'found',
#  'himself',
#  'sitting',
#  'on',
#  'a',
#  'bench',
#  'beside',
#  'Luna',
#  '.',
#  '``',
#  ',',
#  "''",
#  '“',
#  'I',
#  '’',
#  'd',
#  'want',
#  'some',
#  'peace',
#  'and',
#  'quiet',
#  ',',
#  'if',
#  'it',
#  'were',
#  'me',
#  ',',
#  '”',
#  'she',
#  'said',
#  '.',
#  '``',
#  ',',
#  "''",
#  '“',
#  'I',
#  '’',
#  'd',
#  'love',
#  'some',
#  ',',
#  '”',
#  'he',
#  'replied',
#  '.',
#  '``',
#  ',',
#  "''",
#  '“',
#  'I',
#  '’',
#  'll',
#  'distract',
#  'them',
#  'all',
#  ',',
#  '”',
#  'she',
#  'said',
#  '.',
#  '``',
#  ',',
#  "''",
#  '“',
#  'Use',
#  'your',
#  'Cloak.',
#  '”',
#  "''",
#  ',',
#  "''",
#  'And',
#  'before',
#  'he',
#  'could',
#  'say',
#  'a',
#  'word',
#  'she',
#  'had',
#  'cried',
#  ',',
#  '“',
#  'Oooh',
#  ',',
#  'look',
#  ',',
#  'a',
#  'Blibbering',
#  'Humdinger',
#  '!',
#  '”',
#  'and',
#  'pointed',
#  'out',
#  'of',
#  'the',
#  'window',
#  '.',
#  '``',
#  ',',
#  "''",
#  'Everyone',
#  'who',
#  'heard',
#  'looked',
#  'around',
#  ',',
#  'and',
#  'Harry',
#  'slid',
#  'the',
#  'Cloak',
#  'up',
#  'over',
#  'himself',
#  ',',
#  'and',
#  'got',
#  'to',
#  'his',
#  'feet',
#  '.',
#  '``',
#  ',',
#  "''",
#  'Now',
#  'he',
#  'could',
#  'move',
#  'through',
#  'the',
#  'Hall',
#  'without',
#  'interference',
#  '.',
#  '``',
#  ',',
#  "''",
#  'He',
#  'spotted',
#  'Ginny',
#  'two',
#  'tables',
#  'away',
#  ';',
#  'she',
#  'was',
#  'sitting',
#  'with',
#  'her',
#  'head',
#  'on',
#  'her',
#  'mother',
#  '’',
#  's',
#  'shoulder',
#  ':',
#  "''",
#  ',',
#  "''",
#  'He',
#  'saw',
#  'Neville',
#  ',',
#  'the',
#  'sword',
#  'of',
#  'Gryffindor',
#  'lying',
#  'beside',
#  'his',
#  'plate',
#  'as',
#  'he',
#  'ate',
#  ',',
#  'surrounded',
#  'by',
#  'a',
#  'knot',
#  'of',
#  'fervent',
#  'admirers',
#  '.',
#  '``',
#  ',',
#  "''",
#  'Along',
#  'the',
#  'aisle',
#  'between',
#  'the',
#  'tables',
#  'he',
#  'walked',
#  ',',
#  'and',
#  'he',
#  'spotted',
#  'the',
#  'three',
#  'Malfoys',
#  ',',
#  'huddled',
#  'together',
#  'as',
#  'though',
#  'unsure',
#  'whether',
#  'or',
#  'not',
#  'they',
#  'were',
#  'supposed',
#  'to',
#  'be',
#  'there',
#  ',',
#  'but',
#  'nobody',
#  'was',
#  'paying',
#  'them',
#  'any',
#  'attention',
#  '.',
#  '``',
#  ',',
#  "''",
#  'Everywhere',
#  'he',
#  'looked',
#  'he',
#  'saw',
#  'families',
#  'reunited',
#  ',',
#  'and',
#  'finally',
#  ',',
#  'he',
#  'saw',
#  'the',
#  'two',
#  'whose',
#  'company',
#  'he',
#  'craved',
#  'most',
#  '.',
#  '``',
#  ',',
#  "''",
#  '“',
#  'It',
#  '’',
#  's',
#  'me',
#  ',',
#  '”',
#  'he',
#  'muttered',
#  ',',
#  'crouching',
#  'down',
#  'between',
#  'them',
#  '.',
#  '``',
#  ',',
#  "''",
#  '“',
#  'Will',
#  'you',
#  'come',
#  'with',
#  'me',
#  '?',
#  '”',
#  "''",
#  ',',
#  "''",
#  'They',
#  'stood',
#  'up',
#  'at',
#  'once',
#  ',',
#  'and',
#  'together',
#  'he',
#  ',',
#  'Ron',
#  ',',
#  'and',
#  'Hermione',
#  'left',
#  'the',
#  'Great',
#  'Hall',
#  '.',
#  '``',
#  ',',
#  "''",
#  'Great',
#  'chunks',
#  'were',
#  'missing',
#  'from',
#  'the',
#  'marble',
#  'staircase',
#  ',',
#  'part',
#  'of',
#  'the',
#  'balustrade',
#  'gone',
#  ',',
#  'and',
#  'rubble',
#  'and',
#  'bloodstains',
#  'occurred',
#  'every',
#  'few',
#  'steps',
#  'as',
#  'they',
#  ...]

# %%
senttokens_en = sent_tokenize(en_content)

# %%
senttokens_en
# Out:
# ['"The bang was like a cannon blast, and the golden flames that erupted between them, at the dead center of the circle they had been treading, marked the point where the spells collided.',
#  '",\n\n\n"Harry saw Voldemort’s green jet meet his own spell, saw the Elder Wand fly high, dark against the sunrise, spinning across the enchanted ceiling like the head of Nagini, spinning through the air toward the master it would not kill, who had come to take full possession of it at last.',
#  '",\n\n\n"And Harry, with the unerring skill of the Seeker, caught the wand in his free hand as Voldemort fell backward, arms splayed, the slit pupils of the scarlet eyes rolling upward.',
#  '",\n\n\n"Tom Riddle hit the floor with a mundane finality, his body feeble and shrunken, the white hands empty, the snakelike face vacant and unknowing.',
#  '",\n\n\n"Voldemort was dead, killed by his own rebounding curse, and Harry stood with two wands in his hand, staring down at his enemy’s shell.',
#  '",\n\n\n"One shivering second of silence, the shock of the moment suspended: and then the tumult broke around Harry as the screams and the cheers and the roars of the watchers rent the air.',
#  '",\n\n\n"The fierce new sun dazzled the windows as they thundered toward him, and the first to reach him were Ron and Hermione, and it was their arms that were wrapped around him, their incomprehensible shouts that deafened him.',
#  '",\n\n\n"Then Ginny, Neville, and Luna were there, and then all the Weasleys and Hagrid, and Kingsley and McGonagall and Flitwick and Sprout, and Harry could not hear a word that anyone was shouting, nor tell whose hands were seizing him, pulling him, trying to hug some part of him, hundreds of them pressing in, all of them determined to touch the Boy Who Lived, the reason it was over at last.',
#  '",\n\n\n"The sun rose steadily over Hogwarts, and the Great Hall blazed with life and light.',
#  '",\n\n\n"Harry was an indispensable part of the mingled outpourings of jubilation and mourning, of grief and celebration.',
#  '",\n\n\n"They wanted him there with them, their leader and symbol, their savior and their guide, and that he had not slept, that he craved the company of only a few of them, seemed to occur to no one.',
#  '",\n\n\n"He must speak to the bereaved, clasp their hands, witness their tears, receive their thanks, hear the news now creeping in from every quarter as the morning drew on; that the Imperiused up and down the country had come back to themselves, that Death Eaters were fleeing or else being captured, that the innocent of Azkaban were being released at that very moment, and that Kingsley Shacklebolt had been named temporary Minister of Magic.',
#  '...",\n\n\n"They moved Voldemort’s body and laid it in a chamber off the Hall, away from the bodies of Fred, Tonks, Lupin, Colin Creevey, and fifty others who had died fighting him.',
#  '",\n\n\n"McGonagall had replaced the House tables, but nobody was sitting according to House anymore",\n\n\n"All were jumbled together, teachers and pupils, ghosts and parents, centaurs and house- elves, and Firenze lay recovering in a corner, and Grawp peered in through a smashed window, and people were throwing food into his laughing mouth.',
#  '",\n\n\n"After a while, exhausted and drained, Harry found himself sitting on a bench beside Luna.',
#  '",\n\n\n"“I’d want some peace and quiet, if it were me,” she said.',
#  '",\n\n\n"“I’d love some,” he replied.',
#  '",\n\n\n"“I’ll distract them all,” she said.',
#  '",\n\n\n"“Use your Cloak.”",\n\n\n"And before he could say a word she had cried, “Oooh, look, a Blibbering Humdinger!” and pointed out of the window.',
#  '",\n\n\n"Everyone who heard looked around, and Harry slid the Cloak up over himself, and got to his feet.',
#  '",\n\n\n"Now he could move through the Hall without interference.',
#  '",\n\n\n"He spotted Ginny two tables away; she was sitting with her head on her mother’s shoulder:",\n\n\n"He saw Neville, the sword of Gryffindor lying beside his plate as he ate, surrounded by a knot of fervent admirers.',
#  '",\n\n\n"Along the aisle between the tables he walked, and he spotted the three Malfoys, huddled together as though unsure whether or not they were supposed to be there, but nobody was paying them any attention.',
#  '",\n\n\n"Everywhere he looked he saw families reunited, and finally, he saw the two whose company he craved most.',
#  '",\n\n\n"“It’s me,” he muttered, crouching down between them.',
#  '",\n\n\n"“Will you come with me?”",\n\n\n"They stood up at once, and together he, Ron, and Hermione left the Great Hall.',
#  '",\n\n\n"Great chunks were missing from the marble staircase, part of the balustrade gone, and rubble and bloodstains occurred every few steps as they climbed.',
#  '",\n\n\n"Somewhere in the distance they could hear Peeves zooming through the corridors singing a victory song of his own composition:",\n\n\n"“Really gives a feeling for the scope and tragedy of the thing, doesn’t it?” said Ron, pushing open a door to let Harry and Hermione through.',
#  '",\n\n\n"Happiness would come, Harry thought, but at the moment it was muffled by exhaustion, and the pain of losing Fred and Lupin and Tonks pierced him like a physical wound every few steps.',
#  '",\n\n\n"Most of all he felt the most stupendous relief, and a longing to sleep.',
#  '",\n\n\n"But first he owed an explanation to Ron and Hermione, who had stuck with him for so long, and who deserved the truth.',
#  '",\n\n\n"Painstakingly he recounted what he had seen in the Pensieve and what had happened in the forest, and they had not even begun to express all their shock and amazement when at last they arrived at the place to which they had been walking, though none of them had mentioned their destination.',
#  '",\n\n\n"Since he had last seen it, the gargoyle guarding the entrance to the headmaster’s study had been knocked aside; it stood lopsided, looking a little punch-drunk, and Harry wondered whether it would be able to distinguish passwords anymore.',
#  '",\n\n\n"“Can we go up?” he asked the gargoyle.',
#  '",\n\n\n"“Feel free,” groaned the statue.',
#  '",\n\n\n"They clambered over him and onto the spiral stone staircase that moved slowly upward like an escalator.',
#  '",\n\n\n"Harry pushed open the door at the top.',
#  '",\n\n\n"He had one, brief glimpse of the stone Pensieve on the desk where he had left it, and then an earsplitting noise made him cry out, thinking of curses and returning Death Eaters and the rebirth of Voldemort.',
#  '",\n\n\n"All around the walls, the headmasters and headmistresses of Hogwarts were giving him a standing ovation; they waved their hats and in some cases their wigs, they reached through their frames to grip each other’s hands; they danced up and down on the chairs in which they had been painted; Dilys Derwent sobbed unashamedly; Dexter Fortescue was waving his ear-trumpet; and Phineas Nigellus called, in his high, reedy voice, “And let it be noted that Slytherin House played its part!',
#  '",\n\n\n"But Harry had eyes only for the man who stood in the largest portrait directly behind the headmaster’s chair.',
#  '",\n\n\n"Tears were sliding down from behind the half- moon spectacles into the long silver beard, and the pride and the gratitude emanating from him filled Harry with the same balm as phoenix song.',
#  '",\n\n\n"At last, Harry held up his hands, and the portraits fell respectfully silent, beaming and mopping their eyes and waiting eagerly for him to speak.',
#  '",\n\n\n"He directed his words at Dumbledore, however, and chose them with enormous care.',
#  '",\n\n\n"Exhausted and bleary-eyed though he was, he must make one last effort, seeking one last piece of advice.',
#  '",\n\n\n"“The thing that was hidden in the Snitch,” he began, “I dropped it in the forest.',
#  '",\n\n\n"“My dear boy, I do,” said Dumbledore, while his fellow pictures looked confused and curious.',
#  '",\n\n\n"“A wise and courageous decision, but no less than I would have expected of you.',
#  '",\n\n\n"“No one,” said Harry, and Dumbledore nodded his satisfaction.',
#  '",\n\n\n"“I’m going to keep Ignotus’s present, though,” said Harry, and Dumbledore beamed.',
#  '",\n\n\n"“But of course, Harry, it is yours forever, until you pass it on!”",\n\n\n"“And then there’s this.”",\n\n\n"Harry held up the Elder Wand, and Ron and Hermione looked at it with a reverence that, even in his befuddled and sleep-deprived state, Harry did not like to see.',
#  '",\n\n\n"“I don’t want it,” said Harry.',
#  '",\n\n\n"“What?” said Ron loudly.',
#  '",\n\n\n"",“Are you mental?”\n\n\n"“I know it’s powerful,” said Harry wearily.',
#  '",\n\n\n"“But I was happier with mine.',
#  'So ...”",\n\n\n"He rummaged in the pouch hung around his neck, and pulled out the two halves of holly still just connected by the finest thread of phoenix feather.',
#  '",\n\n\n"Hermione had said that they could not be repaired, that the damage was too severe.',
#  '",\n\n\n"All he knew was that if this did not work, nothing would.',
#  '",\n\n\n"He laid the broken wand upon the headmaster’s desk, touched it with the very tip of the Elder Wand, and said, “Reparo.”",\n\n\n"As his wand resealed, red sparks flew out of its end.',
#  '",\n\n\n"Harry knew that he had succeeded.',
#  '",\n\n\n"He picked up the holly and phoenix wand and felt a sudden warmth in his fingers, as though wand and hand were rejoicing at their reunion.',
#  '",\n\n\n"“I’m putting the Elder Wand,” he told Dumbledore, who was watching him with enormous affection and admiration, “back where it came from.',
#  '",\n\n\n"Dumbledore nodded.',
#  '",\n\n\n"They smiled at each other.',
#  '",\n\n\n"“Are you sure?” said Ron.',
#  '",\n\n\n"There was the faintest trace of longing in his voice as he looked at the Elder Wand.',
#  '",\n\n\n"“I think Harry’s right,” said Hermione quietly.',
#  '",\n\n\n"“That wand’s more trouble than it’s worth,” said Harry.',
#  '",\n\n\n"“And quite honestly,” he turned away from the painted portraits, thinking now only of the four-poster bed lying waiting for him in Gryffindor Tower, and wondering whether Kreacher might bring him a sandwich there, “I’ve had enough trouble for a lifetime.”",\n\n\n"Nineteen years later Autumn seemed to arrive suddenly that year.',
#  '",\n\n\n"The morning of the first of September was crisp and golden as an apple, and as the little family bobbed across the rumbling road toward the great sooty station, the fumes of car exhausts and the breath of pedestrians sparkled like cobwebs in the cold air.',
#  '",\n\n\n"Two large cages rattled on top of the laden trolleys the parents were pushing; the owls inside them hooted indignantly, and the redheaded girl trailed tearfully behind her brothers, clutching her father’s arm.',
#  '",\n\n\n"“It won’t be long, and you’ll be going too,” Harry told her.',
#  '",\n\n\n"“Two years,” sniffed Lily.',
#  '",\n\n\n"“I want to go now!”",\n\n\n"The commuters stared curiously at the owls as the family wove its way toward the barrier between platforms nine and ten.',
#  '",\n\n\n"Albus’s voice drifted back to Harry over the surrounding clamor; his sons had resumed the argument they had started in the car.',
#  '",\n\n\n“I won’t!',
#  '"",\n\n\n"“James, give it a rest!” said Ginny.',
#  '",\n\n\n"“I only said he might be,” said James, grinning at his younger brother.',
#  '",\n\n\n"“There’s nothing wrong with that.',
#  '",\n\n\n"But James caught his mother’s eye and fell silent.',
#  '",\n\n\n"The five Potters approached the barrier.',
#  '",\n\n\n"With a slightly cocky look over his shoulder at his younger brother, James took the trolley from his mother and broke into a run.',
#  '",\n\n\n"A moment later, he had vanished.',
#  '",\n\n\n"“You’ll write to me, won’t you?” Albus asked his parents immediately, capitalizing on the momentary absence of his brother.',
#  '",\n\n\n"“Every day, if you want us to,” said Ginny.',
#  '",\n\n\n"“Not every day,” said Albus quickly.',
#  '",\n\n\n"“James says most people only get letters from home about once a month.”",\n\n\n"“We wrote to James three times a week last year,” said Ginny.',
#  '",\n\n\n"“And you don’t want to believe everything he tells you about Hogwarts,” Harry put in.',
#  '",\n\n\n"“He likes a laugh, your brother.”",\n\n\n"Side by side, they pushed the second trolley forward, gathering speed.',
#  '",\n\n\n"As they reached the barrier, Albus winced, but no collision came.',
#  '",\n\n\n"",Instead, the family emerged onto platform nine and three-quarters, which was obscured by thick white steam that was pouring from the scarlet Hogwarts Express.',
#  '"Indistinct figures were swarming through the mist, into which James had already disappeared.',
#  '",\n\n\n"“Where are they?” asked Albus anxiously, peering at the hazy forms they passed as they made their way down the platform.',
#  '",\n\n\n"“Well find them,” said Ginny reassuringly.',
#  '",\n\n\n"But the vapor was dense, and it was difficult to make out anybody’s faces.',
#  '",\n\n\n"Detached from their owners, voices sounded unnaturally loud.',
#  '",\n\n\n"Harry thought he heard Percy discoursing loudly on broomstick regulations, and was quite glad of the excuse not to stop and say hello.',
#  '...",\n\n\n"“I think that’s them, Al,” said Ginny suddenly.',
#  '",\n\n\n"A group of four people emerged from the mist, standing alongside the very last carriage.',
#  '",\n\n\n"Their faces only came into focus when Harry, Ginny, Lily, and Albus had drawn right up to them.',
#  '",\n\n\n"I don’t know exactly where, but I’m not going to go looking for it again.',
#  '",\n\n\n"He might be in Slytherin — ”",\n\n\n"I won’t be in Slytherin!',
#  '"",\n\n\n"Let our contribution not be forgotten!',
#  '"",\n\n\n"Do you agree?',
#  '"",\n\n\n"Does anyone else know where it fell?',
#  '"",\n\n\n"It can stay there.',
#  '",\n\n\n"If I die a natural death like Ignotus, its power will be broken, won’t it?',
#  '",\n\n\n"The previous master will never have been defeated.',
#  '",\n\n\n"That’ll be the end of it.”",\n\n\n"There would be time to talk later, hours and days and maybe years in which to talk.',
#  '",\n\n\n"We did it, we bashed them, wee Potter’s the one, And Voldy’s gone moldy, so now let’s have fun!',
#  '",\n\n\n"But it was applause.',
#  '",']

# %% [markdown]
# # POS TAGGING

# %% [markdown]
# POS Tagging (Parts of Speech Tagging) is a process to mark up the words in text format for a particular part of a speech based on its definition and context. It is responsible for text reading in a language and assigning some specific token (Parts of Speech) to each word. It is also called grammatical tagging.
# Some NLTK POS tagging examples are: CC, CD, EX, JJ, MD, NNP, PDT, PRP$, TO, etc.

# %%
from nltk import pos_tag
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\HP\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# True

# %%
en_post_tag = pos_tag(wordtokens_en)

# %%
en_post_tag[:185]
# Out:
# [('``', '``'),
#  ('The', 'DT'),
#  ('bang', 'NN'),
#  ('was', 'VBD'),
#  ('like', 'IN'),
#  ('a', 'DT'),
#  ('cannon', 'NN'),
#  ('blast', 'NN'),
#  (',', ','),
#  ('and', 'CC'),
#  ('the', 'DT'),
#  ('golden', 'JJ'),
#  ('flames', 'NNS'),
#  ('that', 'WDT'),
#  ('erupted', 'VBD'),
#  ('between', 'IN'),
#  ('them', 'PRP'),
#  (',', ','),
#  ('at', 'IN'),
#  ('the', 'DT'),
#  ('dead', 'JJ'),
#  ('center', 'NN'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('circle', 'NN'),
#  ('they', 'PRP'),
#  ('had', 'VBD'),
#  ('been', 'VBN'),
#  ('treading', 'VBG'),
#  (',', ','),
#  ('marked', 'VBD'),
#  ('the', 'DT'),
#  ('point', 'NN'),
#  ('where', 'WRB'),
#  ('the', 'DT'),
#  ('spells', 'NNS'),
#  ('collided', 'VBD'),
#  ('.', '.'),
#  ('``', '``'),
#  (',', ','),
#  ("''", "''"),
#  ('Harry', 'NNP'),
#  ('saw', 'VBD'),
#  ('Voldemort', 'NNP'),
#  ('’', 'NNP'),
#  ('s', 'VBD'),
#  ('green', 'JJ'),
#  ('jet', 'NN'),
#  ('meet', 'VB'),
#  ('his', 'PRP$'),
#  ('own', 'JJ'),
#  ('spell', 'NN'),
#  (',', ','),
#  ('saw', 'VBD'),
#  ('the', 'DT'),
#  ('Elder', 'NNP'),
#  ('Wand', 'NNP'),
#  ('fly', 'RB'),
#  ('high', 'JJ'),
#  (',', ','),
#  ('dark', 'JJ'),
#  ('against', 'IN'),
#  ('the', 'DT'),
#  ('sunrise', 'NN'),
#  (',', ','),
#  ('spinning', 'VBG'),
#  ('across', 'IN'),
#  ('the', 'DT'),
#  ('enchanted', 'JJ'),
#  ('ceiling', 'NN'),
#  ('like', 'IN'),
#  ('the', 'DT'),
#  ('head', 'NN'),
#  ('of', 'IN'),
#  ('Nagini', 'NNP'),
#  (',', ','),
#  ('spinning', 'VBG'),
#  ('through', 'IN'),
#  ('the', 'DT'),
#  ('air', 'NN'),
#  ('toward', 'IN'),
#  ('the', 'DT'),
#  ('master', 'NN'),
#  ('it', 'PRP'),
#  ('would', 'MD'),
#  ('not', 'RB'),
#  ('kill', 'VB'),
#  (',', ','),
#  ('who', 'WP'),
#  ('had', 'VBD'),
#  ('come', 'VBN'),
#  ('to', 'TO'),
#  ('take', 'VB'),
#  ('full', 'JJ'),
#  ('possession', 'NN'),
#  ('of', 'IN'),
#  ('it', 'PRP'),
#  ('at', 'IN'),
#  ('last', 'JJ'),
#  ('.', '.'),
#  ('``', '``'),
#  (',', ','),
#  ("''", "''"),
#  ('And', 'CC'),
#  ('Harry', 'NNP'),
#  (',', ','),
#  ('with', 'IN'),
#  ('the', 'DT'),
#  ('unerring', 'JJ'),
#  ('skill', 'NN'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('Seeker', 'NNP'),
#  (',', ','),
#  ('caught', 'VBD'),
#  ('the', 'DT'),
#  ('wand', 'NN'),
#  ('in', 'IN'),
#  ('his', 'PRP$'),
#  ('free', 'JJ'),
#  ('hand', 'NN'),
#  ('as', 'IN'),
#  ('Voldemort', 'NNP'),
#  ('fell', 'VBD'),
#  ('backward', 'RB'),
#  (',', ','),
#  ('arms', 'NNS'),
#  ('splayed', 'VBD'),
#  (',', ','),
#  ('the', 'DT'),
#  ('slit', 'NN'),
#  ('pupils', 'NNS'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('scarlet', 'NN'),
#  ('eyes', 'NNS'),
#  ('rolling', 'VBG'),
#  ('upward', 'RB'),
#  ('.', '.'),
#  ('``', '``'),
#  (',', ','),
#  ("''", "''"),
#  ('Tom', 'NNP'),
#  ('Riddle', 'NNP'),
#  ('hit', 'VBD'),
#  ('the', 'DT'),
#  ('floor', 'NN'),
#  ('with', 'IN'),
#  ('a', 'DT'),
#  ('mundane', 'NN'),
#  ('finality', 'NN'),
#  (',', ','),
#  ('his', 'PRP$'),
#  ('body', 'NN'),
#  ('feeble', 'JJ'),
#  ('and', 'CC'),
#  ('shrunken', 'JJ'),
#  (',', ','),
#  ('the', 'DT'),
#  ('white', 'JJ'),
#  ('hands', 'NNS'),
#  ('empty', 'JJ'),
#  (',', ','),
#  ('the', 'DT'),
#  ('snakelike', 'JJ'),
#  ('face', 'NN'),
#  ('vacant', 'NN'),
#  ('and', 'CC'),
#  ('unknowing', 'NN'),
#  ('.', '.'),
#  ('``', '``'),
#  (',', ','),
#  ("''", "''"),
#  ('Voldemort', 'NNP'),
#  ('was', 'VBD'),
#  ('dead', 'JJ'),
#  (',', ','),
#  ('killed', 'VBN'),
#  ('by', 'IN'),
#  ('his', 'PRP$'),
#  ('own', 'JJ'),
#  ('rebounding', 'NN'),
#  ('curse', 'NN'),
#  (',', ','),
#  ('and', 'CC')]

# %% [markdown]
# # Spacy Tagging

# %%
import spacy

# %%
nlp = spacy.load("en_core_web_lg")

# %%
doc = open(en, encoding='utf-8').read()
doc1 = nlp(doc)

# %%
doc1
# Out:
# "The bang was like a cannon blast, and the golden flames that erupted between them, at the dead center of the circle they had been treading, marked the point where the spells collided.",
#
#
# "Harry saw Voldemort’s green jet meet his own spell, saw the Elder Wand fly high, dark against the sunrise, spinning across the enchanted ceiling like the head of Nagini, spinning through the air toward the master it would not kill, who had come to take full possession of it at last.",
#
#
# "And Harry, with the unerring skill of the Seeker, caught the wand in his free hand as Voldemort fell backward, arms splayed, the slit pupils of the scarlet eyes rolling upward.",
#
#
# "Tom Riddle hit the floor with a mundane finality, his body feeble and shrunken, the white hands empty, the snakelike face vacant and unknowing.",
#
#
# "Voldemort was dead, killed by his own rebounding curse, and Harry stood with two wands in his hand, staring down at his enemy’s shell.",
#
#
# "One shivering second of silence, the shock of the moment suspended: and then the tumult broke around Harry as the screams and the cheers and the roars of the watchers rent the air.",
#
#
# "The fierce new sun dazzled the windows as they thundered toward him, and the first to reach him were Ron and Hermione, and it was their arms that were wrapped around him, their incomprehensible shouts that deafened him.",
#
#
# "Then Ginny, Neville, and Luna were there, and then all the Weasleys and Hagrid, and Kingsley and McGonagall and Flitwick and Sprout, and Harry could not hear a word that anyone was shouting, nor tell whose hands were seizing him, pulling him, trying to hug some part of him, hundreds of them pressing in, all of them determined to touch the Boy Who Lived, the reason it was over at last.",
#
#
# "The sun rose steadily over Hogwarts, and the Great Hall blazed with life and light.",
#
#
# "Harry was an indispensable part of the mingled outpourings of jubilation and mourning, of grief and celebration.",
#
#
# "They wanted him there with them, their leader and symbol, their savior and their guide, and that he had not slept, that he craved the company of only a few of them, seemed to occur to no one.",
#
#
# "He must speak to the bereaved, clasp their hands, witness their tears, receive their thanks, hear the news now creeping in from every quarter as the morning drew on; that the Imperiused up and down the country had come back to themselves, that Death Eaters were fleeing or else being captured, that the innocent of Azkaban were being released at that very moment, and that Kingsley Shacklebolt had been named temporary Minister of Magic. ...",
#
#
# "They moved Voldemort’s body and laid it in a chamber off the Hall, away from the bodies of Fred, Tonks, Lupin, Colin Creevey, and fifty others who had died fighting him.",
#
#
# "McGonagall had replaced the House tables, but nobody was sitting according to House anymore",
#
#
# "All were jumbled together, teachers and pupils, ghosts and parents, centaurs and house- elves, and Firenze lay recovering in a corner, and Grawp peered in through a smashed window, and people were throwing food into his laughing mouth.",
#
#
# "After a while, exhausted and drained, Harry found himself sitting on a bench beside Luna.",
#
#
# "“I’d want some peace and quiet, if it were me,” she said.",
#
#
# "“I’d love some,” he replied.",
#
#
# "“I’ll distract them all,” she said.",
#
#
# "“Use your Cloak.”",
#
#
# "And before he could say a word she had cried, “Oooh, look, a Blibbering Humdinger!” and pointed out of the window.",
#
#
# "Everyone who heard looked around, and Harry slid the Cloak up over himself, and got to his feet.",
#
#
# "Now he could move through the Hall without interference.",
#
#
# "He spotted Ginny two tables away; she was sitting with her head on her mother’s shoulder:",
#
#
# "He saw Neville, the sword of Gryffindor lying beside his plate as he ate, surrounded by a knot of fervent admirers.",
#
#
# "Along the aisle between the tables he walked, and he spotted the three Malfoys, huddled together as though unsure whether or not they were supposed to be there, but nobody was paying them any attention.",
#
#
# "Everywhere he looked he saw families reunited, and finally, he saw the two whose company he craved most.",
#
#
# "“It’s me,” he muttered, crouching down between them.",
#
#
# "“Will you come with me?”",
#
#
# "They stood up at once, and together he, Ron, and Hermione left the Great Hall.",
#
#
# "Great chunks were missing from the marble staircase, part of the balustrade gone, and rubble and bloodstains occurred every few steps as they climbed.",
#
#
# "Somewhere in the distance they could hear Peeves zooming through the corridors singing a victory song of his own composition:",
#
#
# "“Really gives a feeling for the scope and tragedy of the thing, doesn’t it?” said Ron, pushing open a door to let Harry and Hermione through.",
#
#
# "Happiness would come, Harry thought, but at the moment it was muffled by exhaustion, and the pain of losing Fred and Lupin and Tonks pierced him like a physical wound every few steps.",
#
#
# "Most of all he felt the most stupendous relief, and a longing to sleep.",
#
#
# "But first he owed an explanation to Ron and Hermione, who had stuck with him for so long, and who deserved the truth.",
#
#
# "Painstakingly he recounted what he had seen in the Pensieve and what had happened in the forest, and they had not even begun to express all their shock and amazement when at last they arrived at the place to which they had been walking, though none of them had mentioned their destination.",
#
#
# "Since he had last seen it, the gargoyle guarding the entrance to the headmaster’s study had been knocked aside; it stood lopsided, looking a little punch-drunk, and Harry wondered whether it would be able to distinguish passwords anymore.",
#
#
# "“Can we go up?” he asked the gargoyle.",
#
#
# "“Feel free,” groaned the statue.",
#
#
# "They clambered over him and onto the spiral stone staircase that moved slowly upward like an escalator.",
#
#
# "Harry pushed open the door at the top.",
#
#
# "He had one, brief glimpse of the stone Pensieve on the desk where he had left it, and then an earsplitting noise made him cry out, thinking of curses and returning Death Eaters and the rebirth of Voldemort.",
#
#
# "All around the walls, the headmasters and headmistresses of Hogwarts were giving him a standing ovation; they waved their hats and in some cases their wigs, they reached through their frames to grip each other’s hands; they danced up and down on the chairs in which they had been painted; Dilys Derwent sobbed unashamedly; Dexter Fortescue was waving his ear-trumpet; and Phineas Nigellus called, in his high, reedy voice, “And let it be noted that Slytherin House played its part!",
#
#
# "But Harry had eyes only for the man who stood in the largest portrait directly behind the headmaster’s chair.",
#
#
# "Tears were sliding down from behind the half- moon spectacles into the long silver beard, and the pride and the gratitude emanating from him filled Harry with the same balm as phoenix song.",
#
#
# "At last, Harry held up his hands, and the portraits fell respectfully silent, beaming and mopping their eyes and waiting eagerly for him to speak.",
#
#
# "He directed his words at Dumbledore, however, and chose them with enormous care.",
#
#
# "Exhausted and bleary-eyed though he was, he must make one last effort, seeking one last piece of advice.",
#
#
# "“The thing that was hidden in the Snitch,” he began, “I dropped it in the forest.",
#
#
# "“My dear boy, I do,” said Dumbledore, while his fellow pictures looked confused and curious.",
#
#
# "“A wise and courageous decision, but no less than I would have expected of you.",
#
#
# "“No one,” said Harry, and Dumbledore nodded his satisfaction.",
#
#
# "“I’m going to keep Ignotus’s present, though,” said Harry, and Dumbledore beamed.",
#
#
# "“But of course, Harry, it is yours forever, until you pass it on!”",
#
#
# "“And then there’s this.”",
#
#
# "Harry held up the Elder Wand, and Ron and Hermione looked at it with a reverence that, even in his befuddled and sleep-deprived state, Harry did not like to see.",
#
#
# "“I don’t want it,” said Harry.",
#
#
# "“What?” said Ron loudly.",
#
#
# "",“Are you mental?”
#
#
# "“I know it’s powerful,” said Harry wearily.",
#
#
# "“But I was happier with mine. So ...”",
#
#
# "He rummaged in the pouch hung around his neck, and pulled out the two halves of holly still just connected by the finest thread of phoenix feather.",
#
#
# "Hermione had said that they could not be repaired, that the damage was too severe.",
#
#
# "All he knew was that if this did not work, nothing would.",
#
#
# "He laid the broken wand upon the headmaster’s desk, touched it with the very tip of the Elder Wand, and said, “Reparo.”",
#
#
# "As his wand resealed, red sparks flew out of its end.",
#
#
# "Harry knew that he had succeeded.",
#
#
# "He picked up the holly and phoenix wand and felt a sudden warmth in his fingers, as though wand and hand were rejoicing at their reunion.",
#
#
# "“I’m putting the Elder Wand,” he told Dumbledore, who was watching him with enormous affection and admiration, “back where it came from.",
#
#
# "Dumbledore nodded.",
#
#
# "They smiled at each other.",
#
#
# "“Are you sure?” said Ron.",
#
#
# "There was the faintest trace of longing in his voice as he looked at the Elder Wand.",
#
#
# "“I think Harry’s right,” said Hermione quietly.",
#
#
# "“That wand’s more trouble than it’s worth,” said Harry.",
#
#
# "“And quite honestly,” he turned away from the painted portraits, thinking now only of the four-poster bed lying waiting for him in Gryffindor Tower, and wondering whether Kreacher might bring him a sandwich there, “I’ve had enough trouble for a lifetime.”",
#
#
# "Nineteen years later Autumn seemed to arrive suddenly that year.",
#
#
# "The morning of the first of September was crisp and golden as an apple, and as the little family bobbed across the rumbling road toward the great sooty station, the fumes of car exhausts and the breath of pedestrians sparkled like cobwebs in the cold air.",
#
#
# "Two large cages rattled on top of the laden trolleys the parents were pushing; the owls inside them hooted indignantly, and the redheaded girl trailed tearfully behind her brothers, clutching her father’s arm.",
#
#
# "“It won’t be long, and you’ll be going too,” Harry told her.",
#
#
# "“Two years,” sniffed Lily.",
#
#
# "“I want to go now!”",
#
#
# "The commuters stared curiously at the owls as the family wove its way toward the barrier between platforms nine and ten.",
#
#
# "Albus’s voice drifted back to Harry over the surrounding clamor; his sons had resumed the argument they had started in the car.",
#
#
# “I won’t!"",
#
#
# "“James, give it a rest!” said Ginny.",
#
#
# "“I only said he might be,” said James, grinning at his younger brother.",
#
#
# "“There’s nothing wrong with that.",
#
#
# "But James caught his mother’s eye and fell silent.",
#
#
# "The five Potters approached the barrier.",
#
#
# "With a slightly cocky look over his shoulder at his younger brother, James took the trolley from his mother and broke into a run.",
#
#
# "A moment later, he had vanished.",
#
#
# "“You’ll write to me, won’t you?” Albus asked his parents immediately, capitalizing on the momentary absence of his brother.",
#
#
# "“Every day, if you want us to,” said Ginny.",
#
#
# "“Not every day,” said Albus quickly.",
#
#
# "“James says most people only get letters from home about once a month.”",
#
#
# "“We wrote to James three times a week last year,” said Ginny.",
#
#
# "“And you don’t want to believe everything he tells you about Hogwarts,” Harry put in.",
#
#
# "“He likes a laugh, your brother.”",
#
#
# "Side by side, they pushed the second trolley forward, gathering speed.",
#
#
# "As they reached the barrier, Albus winced, but no collision came.",
#
#
# "",Instead, the family emerged onto platform nine and three-quarters, which was obscured by thick white steam that was pouring from the scarlet Hogwarts Express.
#
#
# "Indistinct figures were swarming through the mist, into which James had already disappeared.",
#
#
# "“Where are they?” asked Albus anxiously, peering at the hazy forms they passed as they made their way down the platform.",
#
#
# "“Well find them,” said Ginny reassuringly.",
#
#
# "But the vapor was dense, and it was difficult to make out anybody’s faces.",
#
#
# "Detached from their owners, voices sounded unnaturally loud.",
#
#
# "Harry thought he heard Percy discoursing loudly on broomstick regulations, and was quite glad of the excuse not to stop and say hello. ...",
#
#
# "“I think that’s them, Al,” said Ginny suddenly.",
#
#
# "A group of four people emerged from the mist, standing alongside the very last carriage.",
#
#
# "Their faces only came into focus when Harry, Ginny, Lily, and Albus had drawn right up to them.",
#
#
# "I don’t know exactly where, but I’m not going to go looking for it again.",
#
#
# "He might be in Slytherin — ”",
#
#
# "I won’t be in Slytherin!"",
#
#
# "Let our contribution not be forgotten!"",
#
#
# "Do you agree?"",
#
#
# "Does anyone else know where it fell?"",
#
#
# "It can stay there.",
#
#
# "If I die a natural death like Ignotus, its power will be broken, won’t it?",
#
#
# "The previous master will never have been defeated.",
#
#
# "That’ll be the end of it.”",
#
#
# "There would be time to talk later, hours and days and maybe years in which to talk.",
#
#
# "We did it, we bashed them, wee Potter’s the one, And Voldy’s gone moldy, so now let’s have fun!",
#
#
# "But it was applause.",

# %%
for token in doc1[0:180]:
  print(token.text, token.pos_,token.tag_, token.dep_)
# Out:
# " PUNCT `` punct
# The DET DT det
# bang NOUN NN nsubj
# was AUX VBD ccomp
# like SCONJ IN prep
# a DET DT det
# cannon NOUN NN compound
# blast NOUN NN pobj
# , PUNCT , punct
# and CCONJ CC cc
# the DET DT det
# golden ADJ JJ amod
# flames NOUN NNS conj
# that DET WDT nsubj
# erupted VERB VBD relcl
# between ADP IN prep
# them PRON PRP pobj
# , PUNCT , punct
# at ADP IN prep
# the DET DT det
# dead ADJ JJ amod
# center NOUN NN pobj
# of ADP IN prep
# the DET DT det
# circle NOUN NN pobj
# they PRON PRP nsubj
# had AUX VBD aux
# been AUX VBN aux
# treading VERB VBG relcl
# , PUNCT , punct
# marked VERB VBD ROOT
# the DET DT det
# point NOUN NN dobj
# where ADV WRB advmod
# the DET DT det
# spells NOUN NNS nsubj
# collided VERB VBD relcl
# . PUNCT . punct
# " PUNCT '' punct
# , PUNCT , punct
#
#
#
#  SPACE _SP
# " PUNCT '' punct
# Harry PROPN NNP nsubj
# saw VERB VBD ccomp
# Voldemort PROPN NNP poss
# ’s PART POS case
# green ADJ JJ amod
# jet NOUN NN nsubj
# meet VERB VB ccomp
# his DET PRP$ poss
# own ADJ JJ amod
# spell NOUN NN dobj
# , PUNCT , punct
# saw VERB VBD conj
# the DET DT det
# Elder ADJ JJR compound
# Wand PROPN NNP nsubj
# fly VERB VB ccomp
# high ADJ JJ advmod
# , PUNCT , punct
# dark ADJ JJ advcl
# against ADP IN prep
# the DET DT det
# sunrise NOUN NN pobj
# , PUNCT , punct
# spinning VERB VBG advcl
# across ADP IN prep
# the DET DT det
# enchanted VERB VBN amod
# ceiling NOUN NN pobj
# like SCONJ IN prep
# the DET DT det
# head NOUN NN pobj
# of ADP IN prep
# Nagini PROPN NNP pobj
# , PUNCT , punct
# spinning VERB VBG advcl
# through ADP IN prep
# the DET DT det
# air NOUN NN pobj
# toward ADP IN prep
# the DET DT det
# master NOUN NN pobj
# it PRON PRP nsubj
# would VERB MD aux
# not PART RB neg
# kill VERB VB relcl
# , PUNCT , punct
# who PRON WP nsubj
# had AUX VBD aux
# come VERB VBN relcl
# to PART TO aux
# take VERB VB advcl
# full ADJ JJ amod
# possession NOUN NN dobj
# of ADP IN prep
# it PRON PRP pobj
# at ADP IN advmod
# last ADV RB advmod
# . PUNCT . punct
# " PUNCT '' punct
# , PUNCT , punct
#
#
#
#  SPACE _SP
# " PUNCT '' punct
# And CCONJ CC cc
# Harry PROPN NNP nsubj
# , PUNCT , punct
# with ADP IN prep
# the DET DT det
# unerring ADJ JJ amod
# skill NOUN NN pobj
# of ADP IN prep
# the DET DT det
# Seeker PROPN NNP pobj
# , PUNCT , punct
# caught VERB VBD conj
# the DET DT det
# wand NOUN NN dobj
# in ADP IN prep
# his DET PRP$ poss
# free ADJ JJ amod
# hand NOUN NN pobj
# as SCONJ IN mark
# Voldemort PROPN NNP nsubj
# fell VERB VBD advcl
# backward ADV RB advmod
# , PUNCT , punct
# arms NOUN NNS nsubj
# splayed VERB VBN conj
# , PUNCT , punct
# the DET DT det
# slit ADJ JJ compound
# pupils NOUN NNS nsubj
# of ADP IN prep
# the DET DT det
# scarlet ADJ JJ amod
# eyes NOUN NNS pobj
# rolling VERB VBG advcl
# upward ADV RB advmod
# . PUNCT . punct
# " PUNCT '' punct
# , PUNCT , punct
#
#
#
#  SPACE _SP
# " PUNCT '' punct
# Tom PROPN NNP compound
# Riddle PROPN NNP nsubj
# hit VERB VBD ccomp
# the DET DT det
# floor NOUN NN dobj
# with ADP IN prep
# a DET DT det
# mundane ADJ JJ amod
# finality NOUN NN pobj
# , PUNCT , punct
# his DET PRP$ poss
# body NOUN NN nsubj
# feeble ADJ JJ advcl
# and CCONJ CC cc
# shrunken ADJ JJ conj
# , PUNCT , punct
# the DET DT det
# white ADJ JJ amod
# hands NOUN NNS conj
# empty ADJ JJ amod
# , PUNCT , punct
# the DET DT det
# snakelike ADJ JJ amod
# face NOUN NN nsubj
# vacant ADJ JJ advcl
# and CCONJ CC cc
# unknowing ADJ JJ conj
# . PUNCT . punct
# " PUNCT '' punct
# , PUNCT , punct
#
#
#
#  SPACE _SP
# " PUNCT `` punct
# Voldemort PROPN NNP nsubj
# was AUX VBD ccomp
# dead ADJ JJ acomp
# , PUNCT , punct

# %%
print("Verbs:", [token.text for token in doc1 if token.pos_ == "VERB"])
# Out:
# Verbs: ['erupted', 'treading', 'marked', 'collided', 'saw', 'meet', 'saw', 'fly', 'spinning', 'enchanted', 'spinning', 'would', 'kill', 'come', 'take', 'caught', 'fell', 'splayed', 'rolling', 'hit', 'killed', 'stood', 'staring', 'shivering', 'suspended', 'broke', 'rent', 'dazzled', 'thundered', 'reach', 'wrapped', 'deafened', 'could', 'hear', 'shouting', 'tell', 'seizing', 'pulling', 'trying', 'hug', 'pressing', 'determined', 'touch', 'Lived', 'rose', 'blazed', 'mingled', 'wanted', 'slept', 'craved', 'seemed', 'occur', 'must', 'speak', 'clasp', 'witness', 'receive', 'hear', 'creeping', 'drew', 'come', 'fleeing', 'captured', 'released', 'named', 'moved', 'laid', 'died', 'fighting', 'replaced', 'sitting', 'according', 'jumbled', 'lay', 'recovering', 'peered', 'smashed', 'throwing', 'laughing', 'exhausted', 'drained', 'found', 'sitting', '’d', 'want', 'said', '’d', 'love', 'replied', '’ll', 'distract', 'said', 'Use', 'could', 'say', 'cried', 'look', 'pointed', 'heard', 'looked', 'slid', 'got', 'could', 'move', 'spotted', 'sitting', 'saw', 'lying', 'ate', 'surrounded', 'walked', 'spotted', 'huddled', 'supposed', 'paying', 'looked', 'saw', 'reunited', 'saw', 'craved', '’s', 'muttered', 'crouching', 'Will', 'come', 'stood', 'left', 'missing', 'gone', 'occurred', 'climbed', 'could', 'hear', 'zooming', 'singing', 'gives', 'said', 'pushing', 'let', 'would', 'come', 'thought', 'muffled', 'losing', 'pierced', 'felt', 'sleep', 'owed', 'stuck', 'deserved', 'recounted', 'seen', 'happened', 'begun', 'express', 'arrived', 'walking', 'mentioned', 'seen', 'guarding', 'knocked', 'stood', 'looking', 'wondered', 'would', 'distinguish', 'Can', 'go', 'asked', 'Feel', 'groaned', 'clambered', 'moved', 'pushed', 'left', 'made', 'cry', 'thinking', 'returning', 'giving', 'waved', 'reached', 'grip', 'danced', 'painted', 'sobbed', 'waving', 'called', 'let', 'noted', 'played', 'stood', 'sliding', 'emanating', 'filled', 'held', 'fell', 'beaming', 'mopping', 'waiting', 'speak', 'directed', 'chose', 'must', 'make', 'seeking', 'hidden', 'began', 'dropped', 'said', 'looked', 'would', 'expected', 'said', 'nodded', '’m', 'going', 'keep', 'said', 'beamed', 'pass', '’s', 'held', 'looked', 'deprived', 'like', 'see', 'want', 'said', 'said', 'know', '’s', 'said', 'rummaged', 'hung', 'pulled', 'connected', 'said', 'could', 'repaired', 'knew', 'work', 'would', 'laid', 'broken', 'touched', 'said', 'resealed', 'flew', 'knew', 'succeeded', 'picked', 'felt', 'rejoicing', '’m', 'putting', 'told', 'watching', 'came', 'nodded', 'smiled', 'said', 'looked', 'think', 'said', '’s', '’s', 'said', 'turned', 'painted', 'thinking', 'lying', 'waiting', 'wondering', 'might', 'bring', '’ve', 'had', 'seemed', 'arrive', 'bobbed', 'rumbling', 'sparkled', 'rattled', 'pushing', 'hooted', 'trailed', 'clutching', 'wo', '’ll', 'going', 'told', 'sniffed', 'want', 'go', 'stared', 'wove', 'drifted', 'surrounding', 'resumed', 'started', 'wo', 'give', 'said', 'said', 'might', 'said', 'grinning', '’s', 'caught', 'fell', 'approached', 'took', 'broke', 'vanished', '’ll', 'write', 'wo', 'asked', 'capitalizing', 'want', 'said', 'said', 'says', 'get', 'wrote', 'said', 'want', 'believe', 'tells', 'put', 'likes', 'pushed', 'gathering', 'reached', 'winced', 'came', 'emerged', 'obscured', 'pouring', 'swarming', 'disappeared', 'asked', 'peering', 'passed', 'made', 'find', 'said', 'make', 'Detached', 'sounded', 'thought', 'heard', 'discoursing', 'stop', 'say', 'think', '’s', 'said', 'emerged', 'standing', 'came', 'drawn', 'know', '’m', 'going', 'go', 'looking', 'might', 'wo', 'Let', 'forgotten', 'agree', 'know', 'fell', 'can', 'stay', 'die', 'will', 'broken', 'wo', 'will', 'defeated', '’ll', 'would', 'talk', 'talk', 'bashed', '’s', '’s', 'gone', 'let']

# %% [markdown]
# # Treetagger

# %% [markdown]
# !pip install treetaggerwrapper

# %% [markdown]
# import treetaggerwrapper

# %% [markdown]
# !pip show <treetaggerwrapper>

# %% [markdown]
# tagger = treetaggerwrapper.TreeTagger(TAGLANG='en',TAGDIR = '/pip/wheels/46/64/50/b1944d17fbf5b2882438a50bb37b3d9549443ef29e121b9a38')

# %% [markdown]
# # Standford

# %% [markdown]
# !pip install stanfordnlp

# %% [markdown]
# !pip install pycorenlp

# %%
import stanfordnlp

# %%
nlp = stanfordnlp.Pipeline(lang='en', processors='tokenize', tokenize_batch_size = 16)
# Out:
# Use device: gpu
# ---
# Loading: tokenize
# With settings:
# {'model_path': 'C:\\Users\\HP\\stanfordnlp_resources\\en_ewt_models\\en_ewt_tokenizer.pt', 'batch_size': 16, 'lang': 'en', 'shorthand': 'en_ewt', 'mode': 'predict'}
# Done loading processors!
# ---

# %%
doc = nlp(en_content)

# %%
doc.sentences[2].print_dependencies()

# %% [markdown]
# # Pattern

# %% [markdown]
# pip install Pattern

# %%
from pattern.en import parse
from pattern.en import pprint

# %%
en_parse = parse(en_content,
    tokenize=True,
    tags=True,relations=True)
# Out:
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pattern\text\__init__.py in _read(path, encoding, comment)
#     608             yield line
# --> 609     raise StopIteration
#     610
#
# StopIteration:
#
# The above exception was the direct cause of the following exception:
#
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-32-c2cd17f5f7f1> in <module>
#       1 en_parse = parse(en_content,
#       2     tokenize=True,
# ----> 3     tags=True,relations=True)
#
# ~\Anaconda3\lib\site-packages\pattern\text\en\__init__.py in parse(s, *args, **kwargs)
#     167     """ Returns a tagged Unicode string.
#     168     """
# --> 169     return parser.parse(s, *args, **kwargs)
#     170
#     171
#
# ~\Anaconda3\lib\site-packages\pattern\text\__init__.py in parse(self, s, tokenize, tags, chunks, relations, lemmata, encoding, **kwargs)
#    1170             # Tagger (required by chunker, labeler & lemmatizer).
#    1171             if tags or chunks or relations or lemmata:
# -> 1172                 s[i] = self.find_tags(s[i], **kwargs)
#    1173             else:
#    1174                 s[i] = [[w] for w in s[i]]
#
# ~\Anaconda3\lib\site-packages\pattern\text\en\__init__.py in find_tags(self, tokens, **kwargs)
#     112         if kwargs.get("tagset") == UNIVERSAL:
#     113             kwargs.setdefault("map", lambda token, tag: penntreebank2universal(token, tag))
# --> 114         return _Parser.find_tags(self, tokens, **kwargs)
#     115
#     116
#
# ~\Anaconda3\lib\site-packages\pattern\text\__init__.py in find_tags(self, tokens, **kwargs)
#    1111         # ["The", "cat", "purs"] => [["The", "DT"], ["cat", "NN"], ["purs", "VB"]]
#    1112         return find_tags(tokens,
# -> 1113                     lexicon = kwargs.get("lexicon", self.lexicon or {}),
#    1114                       model = kwargs.get("model", self.model),
#    1115                  morphology = kwargs.get("morphology", self.morphology),
#
# ~\Anaconda3\lib\site-packages\pattern\text\__init__.py in __len__(self)
#     374
#     375     def __len__(self):
# --> 376         return self._lazy("__len__")
#     377
#     378     def __iter__(self):
#
# ~\Anaconda3\lib\site-packages\pattern\text\__init__.py in _lazy(self, method, *args)
#     366         """
#     367         if dict.__len__(self) == 0:
# --> 368             self.load()
#     369             setattr(self, method, types.MethodType(getattr(dict, method), self))
#     370         return getattr(dict, method)(self, *args)
#
# ~\Anaconda3\lib\site-packages\pattern\text\__init__.py in load(self)
#     623     def load(self):
#     624         # Arnold NNP x
# --> 625         dict.update(self, (x.split(" ")[:2] for x in _read(self._path) if len(x.split(" ")) > 1))
#     626
#     627 #--- FREQUENCY -------------------------------------------------------------------------------------
#
# ~\Anaconda3\lib\site-packages\pattern\text\__init__.py in <genexpr>(.0)
#     623     def load(self):
#     624         # Arnold NNP x
# --> 625         dict.update(self, (x.split(" ")[:2] for x in _read(self._path) if len(x.split(" ")) > 1))
#     626
#     627 #--- FREQUENCY -------------------------------------------------------------------------------------
#
# RuntimeError: generator raised StopIteration

# %%
pprint(en_parse)

# %% [markdown]
# # Chunking

# %%
pip install stanfordnlp

# %%
import stanfordnlp
stanfordnlp.download('en')   # This downloads the English models for the neural pipeline
nlp = stanfordnlp.Pipeline()
